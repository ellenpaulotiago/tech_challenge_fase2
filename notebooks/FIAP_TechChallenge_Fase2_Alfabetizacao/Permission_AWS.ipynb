# %%
# %sql
SHOW STORAGE CREDENTIALS;

# %%
# %sql
CREATE EXTERNAL LOCATION loc_fiap_alfabetizacao
URL 's3://s3tc2/'
WITH (
  STORAGE CREDENTIAL `trioprd`
)
COMMENT 'External Location do Tech Challenge FIAP';

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
DESCRIBE STORAGE CREDENTIAL `trioprd`;
